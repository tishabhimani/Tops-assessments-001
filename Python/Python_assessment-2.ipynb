# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "C:\\Users\\Dhruvit\\Downloads\\historical_automobile_sales.csv"
pd.read_csv(file_path)
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# 2                  0.20  28238.443                     3137            3
# 3                  1.00  32615.149                     1653            7
# 4                  0.20  23829.233                     1319            4
# ..                  ...        ...                      ...          ...
# 523                0.25  27852.993                     1793            6
# 524                0.07  21183.704                     1028            5
# 525                0.12  15975.589                     1148            9
# 526                0.25  16862.288                     4850            5
# 527                0.34  25240.425                     2319            3
#
#         GDP  Growth_Rate  unemployment_rate  Automobile_Sales  \
# 0    60.223     0.010000                5.4             456.0
# 1    45.986    -0.309594                4.8             555.9
# 2    35.141    -0.308614                3.4             620.0
# 3    45.673     0.230596                4.2             702.8
# 4    52.997     0.138197                5.3             770.4
# ..      ...          ...                ...               ...
# 523  57.169     0.764155                2.6            1579.6
# 524  59.315     0.036180                2.5            1123.4
# 525  19.472    -2.046169                2.5            1685.9
# 526  27.904     0.302179                2.9            2124.6
# 527  13.518    -1.064211                2.1            3538.5
#
#         Vehicle_Type        City
# 0      Supperminicar     Georgia
# 1      Supperminicar    New York
# 2    Mediumfamilycar    New York
# 3      Supperminicar    Illinois
# 4    Smallfamiliycar  California
# ..               ...         ...
# 523     Executivecar    New York
# 524  Smallfamiliycar  California
# 525           Sports  California
# 526  Smallfamiliycar     Georgia
# 527  Smallfamiliycar     Georgia
#
# [528 rows x 15 columns]

# %%
#Q 1: Develop a Line chart using the functionality of pandas to show how automobile sales fluctuate from year to year. 
data = pd.read_csv(file_path)

plt.figure(figsize =(10,6))
plt.plot(data["Year"],data["Automobile_Sales"],marker='o',color="b",linestyle="-",linewidth="2")
plt.xlabel("Year")
plt.ylabel("Automobile_Sales")
plt.title("Automobile sales fluctuate from year to year")
plt.grid()
plt.tight_layout()
plt.show()

# %%
#Q 2: Plot different lines for categories of vehicle type and analyze the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?
# Get unique vehicle types
vehicle_types = data['Vehicle_Type'].unique()

# Set up the plot
plt.figure(figsize=(12, 8))

# Plot a line for each vehicle type
for vehicle in vehicle_types:
    vehicle_data = data[data['Vehicle_Type'] == vehicle]
    plt.plot(vehicle_data['Year'], vehicle_data['Automobile_Sales'], marker='o', label=vehicle)

# Highlight recession periods (where Recession column is 1)
recession_data = data[data['Recession'] == 1]

# Highlight the recession periods with shading
for recession_year in recession_data['Year'].unique():
    plt.axvspan(recession_year - 0.5, recession_year + 0.5, color='gray', alpha=0.3)

plt.title('Automobile Sales Trends by Vehicle Type with Recession Periods')
plt.xlabel('Year')
plt.ylabel('Automobile Sales')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
#Q 3: Use the functionality of Seaborn Library to create a visualization to compare the sales trend per vehicle type for a recession period with a non- recession period.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data (replace 'file_path' with the actual file path)
data = pd.read_csv(file_path)

# Ensure that 'Year' is an integer, and 'Recession' is a categorical variable (0 for non-recession, 1 for recession)
data['Year'] = data['Year'].astype(int)
data['Recession'] = data['Recession'].astype('category')

# Create a new column to represent the recession period vs non-recession
data['Period'] = data['Recession'].map({0: 'Non-Recession', 1: 'Recession'})

# Set up the plot size and style
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Create a lineplot to compare sales trends per vehicle type during recession and non-recession periods
sns.lineplot(data=data, x='Year', y='Automobile_Sales', hue='Vehicle_Type', style='Period', markers=True, dashes=False)

# Add titles and labels
plt.title('Sales Trend Comparison by Vehicle Type: Recession vs Non-Recession Periods')
plt.xlabel('Year')
plt.ylabel('Automobile Sales')

# Display the plot
plt.tight_layout()
plt.show()
